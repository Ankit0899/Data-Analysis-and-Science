# %% [markdown]
# ### Data Visualization With Seaborn

# %%
! pip install seaborn
# Out:
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata

# %%
import seaborn as sns

# %%
### Basic Plotting With Seaborn
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## Create a Scatter Plot

import matplotlib.pyplot as plt

sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title("Scatter Plot of Total Bill vs tip")
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Total Bill vs tip')

# %% [markdown]
# ## Line Plot

# %%
sns.lineplot(x='size',y='total_bill', data=tips)
plt.title("Line plot of Total Bills By Size")
# Out:
# Text(0.5, 1.0, 'Line plot of Total Bills By Size')

# %%
## Categorical Plots
## Bar Plot
sns.barplot(x='day',y='total_bill',data=tips)
plt.title('Bar Plat of total bill ')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## Violin Plot

sns.violinplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Histograms

# %%
sns.histplot(tips['total_bill'],bins=10,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
## KDE Plot
sns.kdeplot(tips['total_bill'],fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ### PairPlot

# %%
sns.pairplot(tips)

# %% [markdown]
# ### HeatMap

# %%
corr=tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd
sales_df=pd.read_csv('data.csv')
sales_df.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
## Plot total sales by Product

plt.figure(figsize=(10,6))
sns.barplot(x='Category',y="Value",data=sales_df,estimator=sum)
plt.title('Total Sales By Product')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Region',y="Value",data=sales_df,estimator=sum)
plt.title('Total Sales By Region')
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.show()
